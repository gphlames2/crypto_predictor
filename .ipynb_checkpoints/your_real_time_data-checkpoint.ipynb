# %%
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from datetime import timedelta
import seaborn as sns

pd.set_option('display.precision',2)
# %config InlineBackend.figure_format = 'retina'
np.set_printoptions(linewidth=160)
header_names = ['id','name','symbol','slug','num_market_pairs','date added','max_supply','circulating_supply','total_supply','platform_id','platform_name','platform_symbol','platform_slug','platform_token','cmc_rank','last_updated','price','volume_24h','percent_change_1h','percent_change_24h','percent_change_7d','percent_change_30d','percent_change_60d','percent_change_90d','market_cap','extracted_time','count']
my_data = pd.read_csv('all_crypto_half_hour.csv',names=header_names)
my_data = pd.DataFrame(my_data)

# %%
modified_data = my_data.drop(['platform_id','platform_name','platform_slug','platform_symbol','slug','platform_token','max_supply','id','extracted_time','count','date added','name','symbol','num_market_pairs','circulating_supply','total_supply','cmc_rank','last_updated','price','market_cap','volume_24h','percent_change_1h','percent_change_24h'],axis=1)
print(len(modified_data))
print(modified_data.isnull().sum()/len(modified_data))
modified_data = modified_data.dropna()
# Out:
# 147500
# percent_change_7d     0.00e+00
# percent_change_30d    1.60e-03
# percent_change_60d    3.66e-03
# percent_change_90d    9.23e-03
# dtype: float64

# %%
modified_data.describe()
# Out:
#        percent_change_7d  percent_change_30d  percent_change_60d  \
# count          147500.00           147264.00           146960.00
# mean               10.42               84.97              356.83
# std               114.68              916.46             4098.77
# min               -74.25              -69.99              -75.04
# 25%                -6.42               -1.21               28.57
# 50%                 1.12               16.77               88.73
# 75%                15.21               62.07              226.21
# max             14074.88            54575.46           248058.84
#
#        percent_change_90d
# count           146138.00
# mean               931.44
# std              10130.91
# min                -82.34
# 25%                 87.00
# 50%                229.11
# 75%                537.37
# max             471389.96

# %%
modified_data = modified_data.loc[modified_data['percent_change_7d'] <= 200]
modified_data = modified_data.loc[modified_data['percent_change_30d'] <= 400 ]
modified_data = modified_data.loc[modified_data['percent_change_60d'] <= 600 ]
modified_data = modified_data.loc[modified_data['percent_change_90d'] <= 800 ]
modified_data.describe()
#modified_data = modified_data.dropna()
#print(modified_data.isnull().sum()/len(modified_data))
# Out:
#        percent_change_7d  percent_change_30d  percent_change_60d  \
# count          119729.00           119729.00           119729.00
# mean                4.20               24.52               94.28
# std                20.05               47.28              105.44
# min               -74.25              -69.99              -75.04
# 25%                -6.03               -2.90               19.14
# 50%                 0.42               11.66               63.14
# 75%                12.81               42.27              143.74
# max               199.63              399.27              599.86
#
#        percent_change_90d
# count           119729.00
# mean               218.43
# std                194.18
# min                -82.34
# 25%                 64.11
# 50%                170.17
# 75%                332.33
# max                799.99

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
labelencoder.fit(my_data.name)
my_data.name = labelencoder.transform(my_data.name)
new_data = pd.concat([my_data.name,my_data.percent_change_7d,my_data.percent_change_30d,my_data.percent_change_60d,my_data.percent_change_90d],axis=1)
new_data.dropna(inplace=True)
new_data.head(100)
X_data = np.array(new_data.drop(['name'],1).astype(float))
Y_data = list(new_data.name)
print(np.array(Y_data).max())
# Out:
# 138
# /var/folders/sx/6_r17hb57w1_ct0g6tkd6p040000gn/T/ipykernel_16158/2359921667.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_data = np.array(new_data.drop(['name'],1).astype(float))

# %%
from sklearn.cluster import KMeans
X_data_scaled = MinMaxScaler().fit_transform(X_data)
Kmeans = KMeans(n_clusters=2,max_iter=600,algorithm='auto')
Kmeans.fit(X_data_scaled)
cluster_list = []
for index in range(1,10):
    kmeans = KMeans(n_clusters=index,init='k-means++')
    kmeans.fit(X_data_scaled)
    cluster_list.append(kmeans.inertia_)
frame = pd.DataFrame({'Clusters':range(1,10),'Cluster_list':cluster_list})
print(Kmeans.inertia_)
fig = plt.figure(figsize=(4,4))
plt.plot(frame['Clusters'],frame['Cluster_list'],marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('inertia values')
# Out:
# 50.68143541730151
# Text(0, 0.5, 'inertia values')

# %%
k_means = KMeans(n_clusters=2)
bitcoin_clusters = []
non_bitcoin_cluster = []
k_means.fit(X_data_scaled)
correct = 0
bitcoin_value: int = 0
for i in range(len(X_data)):
    if i == 0:
        value_to_be_predicted = np.array(X_data[i].astype(float)).reshape(-1,len(X_data[i]))
        prediction = k_means.predict(value_to_be_predicted)
        bitcoin_value = prediction[0]
        bitcoin_clusters.append(Y_data[i])
    else:
        value_to_be_predicted = np.array(X_data[i].astype(float)).reshape(-1,len(X_data[i]))
        prediction = k_means.predict(value_to_be_predicted)
        if prediction[0] == bitcoin_value:
            bitcoin_clusters.append(Y_data[i])
        else:
            pass
bitcoin_clusters = list(set(bitcoin_clusters))

# %%
list_of_coin_names = ['BTC','ETH','LTC','USDT','XMR','XRP','ZEC','XLM','POT','BNB','USDC','SOL','LUNA','ADA',
                      'UST','BUSD','DOGE','AVAX','DOT','SHIB','WBTC']
selected_coins_array = []
coin_index = 0
data_coins = list(my_data['symbol'].unique())

for coin in list_of_coin_names:
    rows = my_data.loc[my_data['symbol']==coin]
    if data_coins.__contains__(coin) and bitcoin_clusters.__contains__(rows['name'].unique()):
        selected_coins_array.append(coin)
    else:
        continue
print(selected_coins_array)

# time_array = []
your_coin = yf.download('BTC-USD',start='2018-01-01',end='2021-12-31')
print(your_coin.shape)
your_coin.head(20)
print(your_coin.isnull().sum()/len(your_coin))
# Out:
# ['BTC', 'ETH', 'LTC', 'USDT', 'XMR', 'XRP', 'ZEC', 'XLM', 'BNB', 'USDC', 'SOL', 'LUNA', 'ADA', 'UST', 'BUSD', 'DOGE', 'AVAX', 'DOT', 'SHIB', 'WBTC']
# [*********************100%***********************]  1 of 1 completed
# (1461, 6)
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
your_coin.tail(20)
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2021-12-12  49354.86  50724.87  48725.85  50098.34   50098.34  21939223599
# 2021-12-13  50114.74  50205.00  45894.85  46737.48   46737.48  32166727776
# 2021-12-14  46709.82  48431.40  46424.50  46612.63   46612.63  34638619079
# 2021-12-15  48379.75  49473.96  46671.96  48896.72   48896.72  36541828520
# 2021-12-16  48900.46  49425.57  47529.88  47665.43   47665.43  27268150947
# 2021-12-17  47653.73  48004.89  45618.21  46202.14   46202.14  32902725329
# 2021-12-18  46219.25  47313.83  45598.44  46848.78   46848.78  26098292690
# 2021-12-19  46853.87  48089.66  46502.95  46707.02   46707.02  25154053861
# 2021-12-20  46707.06  47401.72  45579.81  46880.28   46880.28  30961902129
# 2021-12-21  46886.08  49300.92  46698.77  48936.61   48936.61  27055803928
# 2021-12-22  48937.10  49544.80  48450.94  48628.51   48628.51  24447979559
# 2021-12-23  48626.34  51332.34  48065.84  50784.54   50784.54  28223878108
# 2021-12-24  50806.05  51814.03  50514.50  50822.20   50822.20  24367912228
# 2021-12-25  50854.92  51176.60  50236.71  50429.86   50429.86  19030650914
# 2021-12-26  50428.69  51196.38  49623.11  50809.52   50809.52  20964372926
# 2021-12-27  50802.61  51956.33  50499.47  50640.42   50640.42  24324345758
# 2021-12-28  50679.86  50679.86  47414.21  47588.86   47588.86  33430376883
# 2021-12-29  47623.87  48119.74  46201.50  46444.71   46444.71  30049226299
# 2021-12-30  46490.61  47879.96  46060.31  47178.12   47178.12  26686491018
# 2021-12-31  47169.37  48472.53  45819.95  46306.45   46306.45  36974172400

# %%
your_coin = your_coin.drop(['Adj Close'],axis=1)
your_coin.describe()
# Out:
#            Open      High       Low     Close    Volume
# count   1461.00   1461.00   1461.00   1461.00  1.46e+03
# mean   18356.29  18846.15  17812.71  18375.24  2.57e+10
# std    17751.53  18246.61  17184.15  17760.30  2.12e+10
# min     3236.27   3275.38   3191.30   3236.76  2.92e+09
# 25%     7116.55   7276.66   6898.28   7116.80  8.04e+09
# 50%     9471.21   9652.74   9263.07   9475.28  2.23e+10
# 75%    28841.57  29244.88  28201.99  29001.72  3.62e+10
# max    67549.73  68789.62  66382.06  67566.83  3.51e+11

# %%
correlation = your_coin.corr()
sns.heatmap(correlation,annot=True,linewidths=.5)
plt.show()

# %%
your_coin = your_coin.drop(['High', 'Open', 'Close', 'Volume'], axis=1)

# %%
_,ax = plt.subplots(figsize=(6,3))
your_coin.hist(ax=ax)
# Out:
# array([<AxesSubplot:title={'center':'Low'}>], dtype=object)

# %%
length = your_coin.size
X_train = np.array(your_coin.Low).reshape(-1,1)[:int(length * 0.8)]
X_test  = np.array(your_coin.Low).reshape(-1,1)[int(length * 0.8):]
print(X_train.shape)
print(X_test.shape)
# Out:
# (1168, 1)
# (293, 1)

# %%
scaler = MinMaxScaler()
X_train = np.array(scaler.fit_transform(X_train)).reshape(-1,1)
X_test = np.array(scaler.fit_transform(X_test)).reshape(-1,1)
x_train = []
y_train = []
x_test = []
y_test = []
time_step = 30
for i in range(time_step,len(X_train)):
    x_train.append(X_train[i-time_step:i])
    y_train.append(X_train[i])
for i in range(time_step,len(X_test)):
    x_test.append(X_test[i-time_step:i])
    y_test.append(X_test[i])
x_train, y_train, x_test, y_test = np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)
y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)
x_train = x_train.reshape((len(x_train),time_step,1))
x_test = x_test.reshape((len(x_test),time_step,1))
print(y_train.shape)
x_train.shape
# Out:
# (1138, 1)
# (1138, 30, 1)

# %%
from keras.layers import Dense, LSTM, Bidirectional, GRU, Dropout
from keras.models import Sequential

model = Sequential()
model.add(LSTM(units=30,activation='relu',return_sequences=True,input_shape=(x_train.shape[1],1),dropout=0.1))
model.add(LSTM(units=30,return_sequences=True,activation='relu',dropout=0.1))
model.add(LSTM(units=30,return_sequences=True,activation='relu',dropout=0.1))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])
model.summary()
history = model.fit(x_train,y_train,epochs=30,validation_split=0.1,batch_size=30,verbose=1)
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# 2022-05-10 20:44:42.407246: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 30)            3840
#
#  lstm_1 (LSTM)               (None, 30, 30)            7320
#
#  lstm_2 (LSTM)               (None, 30, 30)            7320
#
#  dense (Dense)               (None, 30, 1)             31
#
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] -
# 35/35 [==============================] - 2s 55ms/step - loss: 7.7040e-04 - accuracy: 9.7656e-04 - val_loss: 0.0749 - val_accuracy: 0.0070
# Epoch 23/30
# 35/35 [==============================] - 2s 47ms/step - loss: 7.8307e-04 - accuracy: 9.7656e-04 - val_loss: 0.0886 - val_accuracy: 0.0067
# Epoch 24/30
# 35/35 [==============================] - 2s 53ms/step - loss: 7.7050e-04 - accuracy: 9.7656e-04 - val_loss: 0.0797 - val_accuracy: 0.0070
# Epoch 25/30
# 35/35 [==============================] - 2s 45ms/step - loss: 7.4794e-04 - accuracy: 9.7656e-04 - val_loss: 0.0772 - val_accuracy: 0.0070
# Epoch 26/30
# 35/35 [==============================] - 2s 48ms/step - loss: 7.5972e-04 - accuracy: 9.7656e-04 - val_loss: 0.0636 - val_accuracy: 0.0073
# Epoch 27/30
# 35/35 [==============================] - 2s 50ms/step - loss: 7.5352e-04 - accuracy: 9.7656e-04 - val_loss: 0.0625 - val_accuracy: 0.0073
# Epoch 28/30
# 35/35 [==============================] - 2s 53ms/step - loss: 7.6132e-04 - accuracy: 9.7656e-04 - val_loss: 0.0728 - val_accuracy: 0.0070
# Epoch 29/30
# 35/35 [==============================] - 2s 46ms/step - loss: 7.5001e-04 - accuracy: 9.7656e-04 - val_loss: 0.0685 - val_accuracy: 0.0070
# Epoch 30/30
# 35/35 [==============================] - 2s 44ms/step - loss: 7.2300e-04 - accuracy: 9.7656e-04 - val_loss: 0.0677 - val_accuracy: 0.0073

# %%
y_pred = model.predict(x_test)
y_pred = np.array(y_pred)[:, -1]
y_pred = scaler.inverse_transform(y_pred)
y_test_lstm = scaler.inverse_transform(y_test)
plt.figure(figsize=(14,5))
plt.plot(y_test_lstm, color = 'red', label = 'Real Bitcoin Price')
plt.plot(y_pred, color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model_gru = Sequential()
model_gru.add(GRU(units=30,activation='relu',return_sequences=True,input_shape=(x_train.shape[1],1),dropout=0.1))
model_gru.add(GRU(units=30,return_sequences=True,activation='relu',dropout=0.1))
model_gru.add(GRU(units=30,return_sequences=True,activation='relu',dropout=0.1))
model_gru.add(Dense(units=1))
model_gru.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])
model_gru.summary()
history_gru = model_gru.fit(x_train,y_train,epochs=30,validation_split=0.1,batch_size=30,verbose=1)
loss_gru = history_gru.history['loss']
val_loss_gru = history_gru.history['val_loss']
epochs = range(len(loss_gru))
plt.plot(epochs, loss_gru, 'r', label='Training loss')
plt.plot(epochs, val_loss_gru, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 30)            2970
#
#  gru_1 (GRU)                 (None, 30, 30)            5580
#
#  gru_2 (GRU)                 (None, 30, 30)            5580
#
#  dense_1 (Dense)             (None, 30, 1)             31
#
# =================================================================
# Total params: 14,161
# Trainable params: 14,161
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] - 7s 58ms/step - loss: 0.0030 - accuracy: 9.7656e-04 - val_loss: 0.2147 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 35/35 [==============================] - 1s 42ms/step - loss: 0.0016 - accuracy: 9.7656e-04 - val_loss: 0.1445 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 35/35 [==============================] - 2s 45ms/step - loss: 0.
# 35/35 [==============================] - 2s 45ms/step - loss: 6.5908e-04 - accuracy: 9.7656e-04 - val_loss: 0.0798 - val_accuracy: 0.0076
# Epoch 25/30
# 35/35 [==============================] - 2s 46ms/step - loss: 6.6569e-04 - accuracy: 9.7656e-04 - val_loss: 0.0750 - val_accuracy: 0.0079
# Epoch 26/30
# 35/35 [==============================] - 2s 48ms/step - loss: 6.7710e-04 - accuracy: 9.7656e-04 - val_loss: 0.0750 - val_accuracy: 0.0079
# Epoch 27/30
# 35/35 [==============================] - 2s 46ms/step - loss: 6.6988e-04 - accuracy: 9.7656e-04 - val_loss: 0.0781 - val_accuracy: 0.0079
# Epoch 28/30
# 35/35 [==============================] - 2s 46ms/step - loss: 6.6947e-04 - accuracy: 9.7656e-04 - val_loss: 0.0756 - val_accuracy: 0.0079
# Epoch 29/30
# 35/35 [==============================] - 3s 73ms/step - loss: 6.4986e-04 - accuracy: 9.7656e-04 - val_loss: 0.0686 - val_accuracy: 0.0082
# Epoch 30/30
# 35/35 [==============================] - 2s 60ms/step - loss: 6.4336e-04 - accuracy: 9.7656e-04 - val_loss: 0.0611 - val_accuracy: 0.0082

# %%
y_pred_gru = model_gru.predict(x_test)
y_pred_gru = np.array(y_pred_gru)[:, -1]
y_pred_gru = scaler.inverse_transform(y_pred_gru)
plt.figure(figsize=(14,5))
plt.plot(scaler.inverse_transform(y_test), color = 'red', label = 'Real Bitcoin Price')
plt.plot(y_pred_gru, color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using GRU')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model_bilstm = Sequential()
#model.add(Dropout(0.2))
model_bilstm.add(Bidirectional(LSTM(units=30,activation='relu',return_sequences=True),input_shape=(x_train.shape[1],1)))
model_bilstm.add(Dropout(0.2))
model_bilstm.add(Bidirectional(LSTM(units=30,return_sequences=True,activation='relu')))
model_bilstm.add(Dropout(0.3))
model_bilstm.add(Bidirectional(LSTM(units=30,return_sequences=True,activation='relu')))
model_bilstm.add(Dropout(0.5))
model_bilstm.add(Dense(units=1))
model_bilstm.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])
model_bilstm.summary()
history_bilstm = model_bilstm.fit(x_train,y_train,epochs=20,validation_split=0.1,batch_size=30,verbose=1)
loss_bilstm = history_bilstm.history['loss']
val_loss_bilstm = history_bilstm.history['val_loss']
epochs = range(len(loss_bilstm))
plt.plot(epochs, loss_bilstm, 'r', label='Training loss')
plt.plot(epochs, val_loss_bilstm, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 30, 60)           7680
#  l)
#
#  dropout (Dropout)           (None, 30, 60)            0
#
#  bidirectional_1 (Bidirectio  (None, 30, 60)           21840
#  nal)
#
#  dropout_1 (Dropout)         (None, 30, 60)            0
#
#  bidirectional_2 (Bidirectio  (None, 30, 60)           21840
#  nal)
#
#  dropout_2 (Dropout)         (None, 30, 60)            0
#
#  dense_2 (Dense)             (None, 30, 1)             61
#
# =================================================================
# Total params: 51,421
# Trainable params: 51,421
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 35/35 [==============================] - 15s 107ms/step - loss: 0.0034 - accuracy: 9.7656e-04 - val_loss: 0.2025 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 35/35 [==============================] - 3s 76ms/step - loss: 0.0014 - accuracy: 9.7656e-04 - val_loss: 0.0879 - val_accuracy: 0.0053
# Epoch 3/20
# 35/35 [==============================] - 2s 69ms/step - loss: 0.0010 - accuracy: 9.7656e-04 - val_loss: 0.1084 - val_accuracy: 0.0026
# Epoch 4/20
# 35/35 [==============================] - 2s 71ms/step - loss: 8.0604e-04 - accuracy: 9.7656e-04 - val_loss: 0.0782 - val_accuracy: 0.0058
# Epoch 5/20
# 35/35 [==============================] - 3s 94ms/step - loss: 7.2366e-04 - accuracy: 9.7656e-04 - val_loss: 0.0482 - val_accuracy: 0.0079
# Epoch 6/20
# 35/35 [==============================] - 3s 76ms/step - loss: 5.9469e-04 - accuracy: 9.7656e-04 - val_loss: 0.0226 - val_accuracy: 0.0088
# Epoch 7/20
# 35/35 [==============================] - 2s 59ms/step - loss: 4.9912e-04 - accuracy: 9.7656e-04 - val_loss: 0.0320 - val_accuracy: 0.0088
# Epoch 8/20
# 35/35 [==============================] - 2s 70ms/step - loss: 4.7665e-04 - accuracy: 9.7656e-04 - val_loss: 0.0475 - val_accuracy: 0.0088
# Epoch 9/20
# 35/35 [==============================] - 3s 79ms/step - loss: 4.0080e-04 - accuracy: 9.7656e-04 - val_loss: 0.3185 - val_accuracy: 0.0088
# Epoch 10/20
# 35/35 [==============================] - 3s 87ms/step - loss: 3.6411e-04 - accuracy: 9.7656e-04 - val_loss: 0.5492 - val_accuracy: 0.0088
# Epoch 11/20
# 35/35 [==============================] - 3s 87ms/step - loss: 3.3669e-04 - accuracy: 9.7656e-04 - val_loss: 0.7970 - val_accuracy: 0.0088
# Epoch 12/20
# 35/35 [==============================] - 3s 79ms/step - loss: 3.4761e-04 - accuracy: 9.7656e-04 - val_loss: 21.0307 - val_accuracy: 0.0088
# Epoch 13/20
# 35/35 [==============================] - 3s 77ms/step - loss: 3.0121e-04 - accuracy: 9.7656e-04 - val_loss: 0.2271 - val_accuracy: 0.0088
# Epoch 14/20
# 35/35 [==============================] - 3s 74ms/step - loss: 3.1124e-04 - accuracy: 9.7656e-04 - val_loss: 77.7856 - val_accuracy: 0.0088
# Epoch 15/20
# 35/35 [==============================] - 3s 88ms/step - loss: 2.8354e-04 - accuracy: 9.7656e-04 - val_loss: 2900.9790 - val_accuracy: 0.0088
# Epoch 16/20
# 35/35 [==============================] - 3s 75ms/step - loss: 2.6604e-04 - accuracy: 9.7656e-04 - val_loss: 0.4085 - val_accuracy: 0.0088
# Epoch 17/20
# 35/35 [==============================] - 2s 64ms/step - loss: 2.5214e-04 - accuracy: 9.7656e-04 - val_loss: 6.8028 - val_accuracy: 0.0088
# Epoch 18/20
# 35/35 [==============================] - 3s 83ms/step - loss: 2.4424e-04 - accuracy: 9.7656e-04 - val_loss: 4022.8511 - val_accuracy: 0.0088
# Epoch 19/20
# 35/35 [==============================] - 3s 84ms/step - loss: 2.5638e-04 - accuracy: 9.7656e-04 - val_loss: 646.2736 - val_accuracy: 0.0088
# Epoch 20/20
# 35/35 [==============================] - 2s 64ms/step - loss: 2.2988e-04 - accuracy: 9.7656e-04 - val_loss: 6912.4458 - val_accuracy: 0.0088

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
model_random_forest = RandomForestRegressor(n_estimators=500,max_depth=30)
random_forest_train = x_train.reshape(len(x_train),30)
random_forest_test = x_test.reshape(len(x_test),30)
model_random_forest.fit(random_forest_train,y_train)
predicted_data = model_random_forest.predict(random_forest_test)
print('Your mean_squared_error is %',mean_squared_error(y_test,predicted_data))
print('Your mean_absolute_error is %',mean_absolute_error(y_test,predicted_data))
# Out:
# /var/folders/sx/6_r17hb57w1_ct0g6tkd6p040000gn/T/ipykernel_16158/1233103989.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_random_forest.fit(random_forest_train,y_train)
# Your mean_squared_error is % 0.009386303564678376
# Your mean_absolute_error is % 0.06907672303577257

# %%
plt.figure(figsize=(14,5))
plt.plot(scaler.inverse_transform(y_test), color = 'red', label = 'Real Bitcoin Price')
plt.plot(scaler.inverse_transform(np.array(predicted_data).reshape(-1,1)), color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
eth_data = yf.download('ETH-USD',start='2022-01-01',end='2022-02-28')
eth_data = eth_data['Low']
eth_x_test = []
eth_y_test = []
for i in range(time_step,len(eth_data)):
    eth_x_test.append(eth_data[i-time_step:i])
    eth_y_test.append(eth_data[i])
eth_x_test, eth_y_test = np.array(eth_x_test).reshape(len(eth_x_test),30), np.array(eth_y_test).reshape(-1,1)
eth_x_test, eth_y_test = np.array(scaler.fit_transform(eth_x_test)), np.array(scaler.fit_transform(eth_y_test))
predictions = model_random_forest.predict(eth_x_test)
print('Your mean square error is %',mean_squared_error(eth_y_test,predictions))
print('Your mean absolute error is %',mean_absolute_error(eth_y_test,predictions))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Your mean square error is % 0.04343166327402393
# Your mean absolute error is % 0.17563402042605541

# %%
plt.figure(figsize=(14,5))
plt.plot(scaler.inverse_transform(eth_y_test), color = 'red', label = 'Real Ethereum Price')
plt.plot(scaler.inverse_transform(np.array(predictions).reshape(-1,1)), color = 'green', label = 'Predicted Ethereum Price')
plt.title('Etherum Price Prediction using random forest')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
btc_data = yf.download('BTC-USD',start='2022-01-01',end='2022-02-28')
btc_data = btc_data['Low']
btc_x_test = []
btc_y_test = []
for i in range(time_step,len(btc_data)):
    btc_x_test.append(btc_data[i-time_step:i])
    btc_y_test.append(btc_data[i])
btc_x_test, btc_y_test = np.array(btc_x_test).reshape(len(btc_x_test),30), np.array(btc_y_test).reshape(-1,1)
btc_x_test, btc_y_test= np.array(scaler.fit_transform(btc_x_test)), np.array(scaler.fit_transform(btc_y_test))
predictions_btc = np.array(model_random_forest.predict(btc_x_test)).reshape(-1,1)
print('Your mean_squared_error is %',mean_squared_error(btc_y_test,predictions_btc))
print('Your mean_absolute_error is %',mean_absolute_error(btc_y_test,predictions_btc))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Your mean_squared_error is % 0.04197609335172738
# Your mean_absolute_error is % 0.16005154999496388

# %%
plt.figure(figsize=(14,5))
plt.plot(scaler.inverse_transform(btc_y_test), color = 'red', label = 'Real Bitcoin Price')
plt.plot(scaler.inverse_transform(predictions_btc), color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using random forest')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
btc_x_test_lstm = btc_x_test.reshape((len(btc_x_test),30,1))
predictions_lstm_btc = model.predict(btc_x_test_lstm)
predictions_lstm_btc = np.array(predictions_lstm_btc[:, -1])
print('Your mean square error is %',mean_squared_error(btc_y_test,predictions_lstm_btc))
print('Your mean absolute error is %',mean_absolute_error(btc_y_test,predictions_lstm_btc))
# Out:
# Your mean square error is % 0.08299070653615245
# Your mean absolute error is % 0.23217173405182062

# %%
plt.figure(figsize=(14,5))
plt.plot(scaler.inverse_transform(btc_y_test), color = 'red', label = 'Real Bitcoin Price')
plt.plot(scaler.inverse_transform(predictions_lstm_btc), color = 'green', label = 'Predicted Bitcoin Price')
plt.title('Bitcoin Price Prediction using LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
